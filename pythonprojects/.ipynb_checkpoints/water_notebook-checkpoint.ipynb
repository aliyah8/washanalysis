# %% [markdown]
# # The first part of the analysis is done on drinking water data retreived from WHO/UNICEF.  ****

# %%
import sys
import pandas as pd
import numpy
import matplotlib

# %%
df= pd.read_csv("../input/washdataset/washdash-download.csv")

# %%
df.head()
# Out:
#   Type                     Region Residence Type Service Type  Year  Coverage  \
# 0  sdg  Australia and New Zealand          total   Sanitation  2000  39.38183
# 1  sdg  Australia and New Zealand          total   Sanitation  2000   0.00000
# 2  sdg  Australia and New Zealand          total   Sanitation  2000   0.00000
# 3  sdg  Australia and New Zealand          total   Sanitation  2000  60.61081
# 4  sdg  Australia and New Zealand          total   Sanitation  2000   0.00736
#
#      Population           Service level
# 0  9.028221e+06           Basic service
# 1  0.000000e+00         Limited service
# 2  0.000000e+00         Open defecation
# 3  1.389493e+07  Safely managed service
# 4  1.686995e+03              Unimproved

# %%
df['Service Type']
# Out:
# 0           Sanitation
# 1           Sanitation
# 2           Sanitation
# 3           Sanitation
# 4           Sanitation
#              ...
# 3750    Drinking water
# 3751    Drinking water
# 3752    Drinking water
# 3753    Drinking water
# 3754    Drinking water
# Name: Service Type, Length: 3755, dtype: object

# %%
waterdf = df[df['Service Type'] == 'Drinking water']

# %%
waterdf.head()
# Out:
#   Type                     Region Residence Type    Service Type  Year  \
# 5  sdg  Australia and New Zealand          total  Drinking water  2000
# 6  sdg  Australia and New Zealand          rural  Drinking water  2000
# 7  sdg  Australia and New Zealand          urban  Drinking water  2000
# 8  sdg  Australia and New Zealand          total  Drinking water  2000
# 9  sdg  Australia and New Zealand          rural  Drinking water  2000
#
#    Coverage    Population    Service level
# 5  99.76073  2.286998e+07   At least basic
# 6  99.20021  3.516825e+06   At least basic
# 7   7.91597  1.534088e+06    Basic service
# 8   0.00000  0.000000e+00  Limited service
# 9   0.00000  0.000000e+00  Limited service

# %%
waterdf_total = waterdf[waterdf['Residence Type'] == 'total']

# %%
waterdf_total.head()
# Out:
#    Type                     Region Residence Type    Service Type  Year  \
# 5   sdg  Australia and New Zealand          total  Drinking water  2000
# 8   sdg  Australia and New Zealand          total  Drinking water  2000
# 12  sdg  Australia and New Zealand          total  Drinking water  2000
# 15  sdg  Australia and New Zealand          total  Drinking water  2000
# 23  sdg  Australia and New Zealand          total  Drinking water  2001
#
#     Coverage    Population    Service level
# 5   99.76073  2.286998e+07   At least basic
# 8    0.00000  0.000000e+00  Limited service
# 12   0.05244  1.202292e+04    Surface water
# 15   0.18683  4.283043e+04       Unimproved
# 23  99.75993  2.312083e+07   At least basic

# %%
waterdf_total = waterdf_total.drop(['Population', 'Type', 'Residence Type', 'Service Type'], axis =1)
waterdf_total.head()
# Out:
#                        Region  Year  Coverage    Service level
# 5   Australia and New Zealand  2000  99.76073   At least basic
# 8   Australia and New Zealand  2000   0.00000  Limited service
# 12  Australia and New Zealand  2000   0.05244    Surface water
# 15  Australia and New Zealand  2000   0.18683       Unimproved
# 23  Australia and New Zealand  2001  99.75993   At least basic

# %%
waterdf_spread = pd.pivot_table(waterdf_total, values = 'Coverage', index=['Region','Year'], columns = 'Service level').reset_index()
waterdf_spread.head()
# Out:
# Service level                     Region  Year  At least basic  Basic service  \
# 0              Australia and New Zealand  2000        99.76073            NaN
# 1              Australia and New Zealand  2001        99.75993            NaN
# 2              Australia and New Zealand  2002        99.76086            NaN
# 3              Australia and New Zealand  2003        99.77940            NaN
# 4              Australia and New Zealand  2004        99.79771            NaN
#
# Service level  Limited service  Safely managed service  Surface water  \
# 0                          0.0                     NaN        0.05244
# 1                          0.0                     NaN        0.05288
# 2                          0.0                     NaN        0.05244
# 3                          0.0                     NaN        0.04551
# 4                          0.0                     NaN        0.03870
#
# Service level  Unimproved
# 0                 0.18683
# 1                 0.18719
# 2                 0.18670
# 3                 0.17509
# 4                 0.16359

# %%
waterdf_spread.loc[waterdf_spread['Basic service'].isnull(), 'Basic service'] = waterdf_spread['At least basic']
waterdf_spread = waterdf_spread.drop(['At least basic'], axis = 1)
waterdf=waterdf_spread
waterdf.head()
# Out:
# Service level                     Region  Year  Basic service  \
# 0              Australia and New Zealand  2000       99.76073
# 1              Australia and New Zealand  2001       99.75993
# 2              Australia and New Zealand  2002       99.76086
# 3              Australia and New Zealand  2003       99.77940
# 4              Australia and New Zealand  2004       99.79771
#
# Service level  Limited service  Safely managed service  Surface water  \
# 0                          0.0                     NaN        0.05244
# 1                          0.0                     NaN        0.05288
# 2                          0.0                     NaN        0.05244
# 3                          0.0                     NaN        0.04551
# 4                          0.0                     NaN        0.03870
#
# Service level  Unimproved
# 0                 0.18683
# 1                 0.18719
# 2                 0.18670
# 3                 0.17509
# 4                 0.16359

# %%
waterdf['Region'].unique()
# Out:
# array(['Australia and New Zealand', 'Central and Southern Asia',
#        'Eastern and South-Eastern Asia', 'Europe and Northern America',
#        'Latin America and the Caribbean',
#        'Northern Africa and Western Asia', 'Oceania',
#        'Sub-Saharan Africa'], dtype=object)

# %%
waterdf_aus = waterdf[waterdf['Region'] == 'Australia and New Zealand']
waterdf_csa = waterdf[waterdf['Region'] == 'Central and Southern Asia']
waterdf_lac = waterdf[waterdf['Region'] == 'Latin America and the Caribbean']
waterdf_nawa = waterdf[waterdf['Region'] == 'Northern Africa and Western Asia']
waterdf_oce = waterdf[waterdf['Region'] == 'Oceania']
waterdf_ssa = waterdf[waterdf['Region'] == 'Sub-Saharan Africa']

# %%
import matplotlib.pyplot as plt

# %%
waterdf_aus.head()
# Out:
# Service level                     Region  Year  Basic service  \
# 0              Australia and New Zealand  2000       99.76073
# 1              Australia and New Zealand  2001       99.75993
# 2              Australia and New Zealand  2002       99.76086
# 3              Australia and New Zealand  2003       99.77940
# 4              Australia and New Zealand  2004       99.79771
#
# Service level  Limited service  Safely managed service  Surface water  \
# 0                          0.0                     NaN        0.05244
# 1                          0.0                     NaN        0.05288
# 2                          0.0                     NaN        0.05244
# 3                          0.0                     NaN        0.04551
# 4                          0.0                     NaN        0.03870
#
# Service level  Unimproved
# 0                 0.18683
# 1                 0.18719
# 2                 0.18670
# 3                 0.17509
# 4                 0.16359

# %%
waterdf_aus
# Out:
# Service level                     Region  Year  Basic service  \
# 0              Australia and New Zealand  2000       99.76073
# 1              Australia and New Zealand  2001       99.75993
# 2              Australia and New Zealand  2002       99.76086
# 3              Australia and New Zealand  2003       99.77940
# 4              Australia and New Zealand  2004       99.79771
# 5              Australia and New Zealand  2005       99.81579
# 6              Australia and New Zealand  2006       99.83363
# 7              Australia and New Zealand  2007       99.85130
# 8              Australia and New Zealand  2008       99.86884
# 9              Australia and New Zealand  2009       99.88629
# 10             Australia and New Zealand  2010       99.90365
# 11             Australia and New Zealand  2011       99.92094
# 12             Australia and New Zealand  2012       99.93811
# 13             Australia and New Zealand  2013       99.95519
# 14             Australia and New Zealand  2014       99.96775
# 15             Australia and New Zealand  2015       99.97488
# 16             Australia and New Zealand  2017       99.97479
#
# Service level  Limited service  Safely managed service  Surface water  \
# 0                          0.0                     NaN        0.05244
# 1                          0.0                     NaN        0.05288
# 2                          0.0                     NaN        0.05244
# 3                          0.0                     NaN        0.04551
# 4                          0.0                     NaN        0.03870
# 5                          0.0                     NaN        0.03201
# 6                          0.0                     NaN        0.02543
# 7                          0.0                     NaN        0.01894
# 8                          0.0                     NaN        0.00000
# 9                          0.0                     NaN        0.00000
# 10                         0.0                     NaN        0.00000
# 11                         0.0                     NaN        0.00000
# 12                         0.0                     NaN        0.00000
# 13                         0.0                     NaN        0.00000
# 14                         0.0                     NaN        0.00000
# 15                         0.0                     NaN        0.00000
# 16                         0.0                     NaN        0.00000
#
# Service level  Unimproved
# 0                 0.18683
# 1                 0.18719
# 2                 0.18670
# 3                 0.17509
# 4                 0.16359
# 5                 0.15221
# 6                 0.14095
# 7                 0.12976
# 8                 0.13116
# 9                 0.11371
# 10                0.09635
# 11                0.07906
# 12                0.06189
# 13                0.04481
# 14                0.03225
# 15                0.02512
# 16                0.02521

# %%
from matplotlib import pyplot
sdg_regions = [waterdf_aus, waterdf_csa, waterdf_lac, waterdf_nawa, waterdf_oce, waterdf_ssa]
sdg_region_title = ['Australia and New Zealand', 
                   'Central and Southern Asia',
                   'Latin America and the Caribbean', 
                   'Northern Africa and Western Asia', 
                   'Oceania', 
                   'Sub-Saharan Africa']
index = 0
for region in sdg_regions: 
        title = sdg_region_title[index]
        
        plt.plot(region['Year'], region['Surface water'], fillstyle = 'full', color = 'yellowgreen', marker = '.', label = "Surface water")
        plt.plot(region['Year'], region['Basic service'], fillstyle = 'full',color = 'lightseagreen', marker = '^', label = "Basic")
        plt.plot(region['Year'], region['Limited service'], fillstyle = 'full',color = 'royalblue', marker = '^', label = 'Limited')
        plt.plot(region['Year'], region['Unimproved'],fillstyle = 'full', color = 'mediumpurple', marker ='.', label = 'Unimproved')
        plt.plot(region['Year'], region['Safely managed service'], fillstyle = 'full',color = 'black', marker = '.', label = "Safely managed service")
        
        plt.legend(loc='upper center', bbox_to_anchor=(1.45, 0.8), shadow=True, ncol=1)
        plt.xticks(range(2000,2017,16))
        plt.xlabel('Year')
        plt.ylabel('Percent Coverage')
        plt.title(title)
        plt.show()
        
        image_title =  'Plot of Water Service Levels Across the world'
        
        index += 1

# %%
import numpy as np

# %%
from matplotlib import pyplot
sdg_regions = [waterdf_aus,waterdf_nawa, waterdf_oce]
sdg_region_title = ['Australia and New Zealand', 
                   'Northern Africa and Western Asia', 
                   'Oceania']
index = 0
for region in sdg_regions: 
    title = sdg_region_title[index]
    x = region['Year']
    y2 = region['Basic service']
    y3 = region['Limited service']
    y4 = region['Unimproved']
    y5 = region['Surface water']
    colors=['#FF9070','#FCD17A','#FDF3BF', '#4CC4E7','#4D8CBF']
        
    y = np.vstack([y2,y3,y4,y5])

    labels = ["Basic service", "Limited service", "Unimproved", "Surface water"]
    fig, ax = plt.subplots()
    ax.stackplot(x,y2,y3,y4,y5, labels=labels, colors=colors)
    plt.legend(loc='upper center', bbox_to_anchor=(1.45, 0.8), shadow=True, ncol=1)
    plt.xticks(range(2000,2017,16))
    plt.xlabel('Year')
    plt.ylabel('Percent Coverage')
    plt.title(title)
    plt.show()
    index += 1

# %%
from matplotlib import pyplot
sdg_regions = [waterdf_csa, waterdf_lac, waterdf_ssa]
sdg_region_title = [
                   'Central and Southern Asia',
                   'Latin America and the Caribbean',
                   'Sub-Saharan Africa']
index = 0
for region in sdg_regions: 
    title = sdg_region_title[index]
    x = region['Year']
    y1 = region['Safely managed service']
    y2 = region['Basic service']
    y3 = region['Limited service']
    y4 = region['Unimproved']
    y5 = region['Surface water']

    y = np.vstack([y1,y2,y3,y4,y5])

    labels = ["Safely managed service ", "Basic service", "Limited service", "Unimproved", 
        "Surface water"]    

    colors=['#FF9070','#FCD17A','#FDF3BF', '#4CC4E7','#4D8CBF']
    fig, ax = plt.subplots()
    ax.stackplot(x,y1,y2,y3,y4,y5, labels=labels, colors=colors)
    plt.legend(loc='upper center', bbox_to_anchor=(1.45, 0.8), shadow=True, ncol=1)
    plt.xticks(range(2000,2017,16))
    plt.xlabel('Year')
    plt.ylabel('Percent Coverage')
    plt.title(title)
    plt.show()
    index += 1

# %%
plt.style.use('dark_background')

waterdf.groupby('Year')['Safely managed service'].mean().plot(kind='bar', figsize=(10, 6))
plt.suptitle('Mean of the Safely Managed Service by Year', fontsize=14)
plt.ylabel('Safely Managed Service Population')
plt.xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')

# %%
waterdf.groupby('Year')['Unimproved'].median().plot(kind='bar', figsize=(10, 6))
plt.suptitle('Mean of the Unimproved Water Service by Year', fontsize=14)
plt.ylabel('Unimproved Population')
plt.xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')

# %% [markdown]
# # Medians of Different Water services by Year

# %%
waterdf.groupby('Year')['Safely managed service', 'Basic service', 'Limited service','Unimproved', 'Surface water'].median().plot(kind='bar', figsize=(10, 6))
plt.suptitle('Medians of different water services by Year', fontsize=14)
plt.ylabel('Unimproved Population')
plt.xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')

# %%
waterdf.columns=['Region','Year','Basic Water','Limited Water','Safely Managed Water','Surface water','Unimproved water']

# %%
## Transforming Hygiene and Sanitation data to merge them to Drinking Water and look at the trends

# %%
import pandas as pd
hygiene = pd.read_csv("../input/hygienecleaned/hygiene_cleaned.csv")
hygiene=hygiene.drop(['Unnamed: 0'], axis=1)
hygiene.columns=['Region', 'Year', 'Basic Hygiene','Limited Hygiene','No handwashing facility']
sanitation=pd.read_csv("../input/sanitationcleaned/sanitation_data(new).csv")
sanitation=sanitation.drop(['Unnamed: 0'], axis=1)
sanitation.columns=['Region', 'Year', 'Basic Sanitation','Limited Sanitation','Open Defecation','Safely Managed Sanitation', 'Unimproved Sanitation']

# %% [markdown]
# We are merging sanitation and water data on Year and Region columns

# %%
newdf=pd.merge(sanitation, waterdf, how='left', left_on=['Year','Region'], right_on = ['Year', 'Region'])

# %% [markdown]
# Now, merging sanitation+water data with hygiene data on Year and Region columns

# %%
masterdf=pd.merge(newdf, hygiene, how='left', left_on=['Year', 'Region'],right_on=['Year', 'Region'])

# %% [markdown]
# Our master dataframe we are going to use to look at trends among all three: hygiene, sanitation and water.

# %%
masterdf.head()
# Out:
#                       Region  Year  Basic Sanitation  Limited Sanitation  \
# 0  Australia and New Zealand  2000          39.38183                 0.0
# 1  Australia and New Zealand  2001          39.25925                 0.0
# 2  Australia and New Zealand  2002          39.13418                 0.0
# 3  Australia and New Zealand  2003          39.00791                 0.0
# 4  Australia and New Zealand  2004          38.88287                 0.0
#
#    Open Defecation  Safely Managed Sanitation  Unimproved Sanitation  \
# 0              0.0                   60.61081                0.00736
# 1              0.0                   60.73339                0.00736
# 2              0.0                   60.85847                0.00735
# 3              0.0                   60.98474                0.00735
# 4              0.0                   61.10978                0.00735
#
#    Basic Water  Limited Water  Safely Managed Water  Surface water  \
# 0     99.76073            0.0                   NaN        0.05244
# 1     99.75993            0.0                   NaN        0.05288
# 2     99.76086            0.0                   NaN        0.05244
# 3     99.77940            0.0                   NaN        0.04551
# 4     99.79771            0.0                   NaN        0.03870
#
#    Unimproved water  Basic Hygiene  Limited Hygiene  No handwashing facility
# 0           0.18683            NaN              NaN                      NaN
# 1           0.18719            NaN              NaN                      NaN
# 2           0.18670            NaN              NaN                      NaN
# 3           0.17509            NaN              NaN                      NaN
# 4           0.16359            NaN              NaN                      NaN

# %% [markdown]
# # Following plot demonstrates the Median Percentage Coverages for Basic Hygiene, Basic Water Service and Basic Sanitation around the world in given years.
# # We are aiming to find trends that are present.

# %%
masterdf.groupby('Year')['Basic Hygiene', 'Basic Water','Basic Sanitation'].median().plot(kind='bar', figsize=(10, 6))
plt.suptitle('Medians For Basic Hygiene, Basic Water Service and Basic Sanitation around the world', fontsize=14)
plt.ylabel('Percentage Coverage')
plt.xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')

# %% [markdown]
# # Following plot demonstrates the Median Percentage Coverages for Unimproved Sanitation, Unimproved Water and No Handwashing Facility around the world in given years.
# # We are aiming to find trends that are present.

# %%
masterdf.groupby('Year')['Unimproved Sanitation','Unimproved water', 'No handwashing facility'].median().plot(kind='bar', figsize=(10, 6))
plt.suptitle('Medians For No Handwashing Facility and No water service around the world', fontsize=14)
plt.ylabel('Percentage Coverage')
plt.xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')

# %% [markdown]
# # Following plot demonstrates the Median Percentage Coverages for Limited Hygiene, Limited Water Service and Limited Sanitation around the world in given years.
# # We are aiming to find trends that are present.

# %%
masterdf.groupby('Year')['Limited Hygiene', 'Limited Water','Limited Sanitation'].median().plot(kind='bar', figsize=(10, 6))
plt.suptitle('Medians For Limited Hygiene , Limited Sanitation and Limited Water Service around the world', fontsize=14)
plt.ylabel('Percentage Coverage')
plt.xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')
